# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size=0.2, random_state=42)

# %%
# Sequential에 층을 추가하는 함수 add()
model = keras.Sequential()
model.add(keras.layers.Dense(100, activation='sigmoid', input_shape=(784,)))
model.add(keras.layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
adagrad = keras.optimizers.Adagrad()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2398 - accuracy: 0.9111
# Epoch 2/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2310 - accuracy: 0.9160
# Epoch 3/5
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2218 - accuracy: 0.9188
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2167 - accuracy: 0.9196
# Epoch 5/5
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2093 - accuracy: 0.9226

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3080 - accuracy: 0.8907
# [0.3080388307571411, 0.890749990940094]

# %%
# 기본 RMSprop : 0.8700000047683716
# 학습률 0.9 SGD : 0.8684166669845581
# 학습률 0.01 SGD :  0.8792499899864197
# 모멘텀 0.9 :  0.890749990940094
# 모멘텀 0.9 + 네스테로프모멘텀최적화사용 : 0.8914999961853027
# 적응적 학습률 Adagard : 0.8929166793823242
# 모멘텀최적화+RMSprop장점=Adam : 0.890749990940094
